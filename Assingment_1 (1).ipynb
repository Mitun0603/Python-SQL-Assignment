# %%
print("hello world")
# Out:
# hello world

# %%
# --- Example rewritten for simplicity ---
# keywords: special words : if, else, while, for, import, return, class, def
# identifers: variable, function, class, constants
# variable: can contain letter, numbers and underscore.
# can't start with a number.

# %%
name = "puja"

# %%
print("hello " + name)
# Out:
# hello puja

# %%
age = 10

# %%
# --- Example rewritten for simplicity ---
if age >=18:
  print('adult')
else:
  print('not adult')
# Out:
# not adult

# %%
if age >=18: #if age is equal or greater than 18 print below statement
  print('adult')
else: #otherwise print this statement
  print('not adult')
# Out:
# not adult

# %%
def python_session(name):
  print('first session for ' + name)

# %%
python_session('madhura')
# Out:
# first session for madhura

# %%
# --- Example rewritten for simplicity ---
python_session('radhika')
# Out:
# first session for radhika

# %%
# --- Example rewritten for simplicity ---
python_session('Vishnu')
# Out:
# first session for Vishnu

# %%
# --- Example rewritten for simplicity ---
python_session('RenuKA')
# Out:
# first session for RenuKA

# %%
# --- Example rewritten for simplicity ---
python_session('mANOJ')
# Out:
# first session for mANOJ

# %%
# --- Example rewritten for simplicity ---
def python_session_new():
  print('first session, learning python 2nd statement')

# %%
# --- Example rewritten for simplicity ---
python_session_new()
# Out:
# first session, learning python 2nd statement

# %%
# --- Example rewritten for simplicity ---
python_session_new()
# Out:
# first session, learning python 2nd statement

# %%
# hw: create a function, it should have 3 arguments and it should print sum of the three arguments. The three arguments should be numbers

# %%
# --- Example rewritten for simplicity ---
no_1=10
no_2=20
no_3=30
name="apple"
no_4=4.1
def sum_no(no_1, no_2, no_3):
  print(no_1+no_2+no_3)

no_bool = True

print('Second print',no_1+no_2+no_3)
# Out:
# Second print 60

# %%
# --- Example rewritten for simplicity ---
sum_no(10, 20, 50)
# Out:
# 80

# %%
# --- Example rewritten for simplicity ---
print(type(no_1))
print(type(no_4))
print(type(no_bool))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# --- Example rewritten for simplicity ---
first = 1 # int
second = 2 # int
third = 5.6 # float
fourth = 'apple' # string
fifth = True # bool
sixth = 'true' # string
seventh = 'no' # string
eighth = 8.1 # float
ninth = "mango" # string
tenth = first #int

# %%
# --- Example rewritten for simplicity ---
print(tenth)
# Out:
# 1

# %%
# --- Example rewritten for simplicity ---
print(type(tenth))
# Out:
# <class 'int'>

# %%
# --- Example rewritten for simplicity ---
first = 100
second = 8

# %%
# --- Example rewritten for simplicity ---
first + second
# Out:
# 108

# %%
# --- Example rewritten for simplicity ---
first - second
# Out:
# 92
